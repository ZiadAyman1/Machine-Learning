# %% [markdown]
# # GUC NETW 1003 Kmeans Assginmnet

# %% [markdown]
# Objective: exercise is to learn how to use build and use  kmeans clustering algortrithm
#
# At the end of this lab you will be able to
# > 1. Build and run a K-means algorithm.
# > 2. Know how to evalute K-means Algorithm
# > 2. Understand the effect of the parmeters ont he perfromance of the algorithm .
# > 3. Understand the effect of distance.

# %% [markdown]
# ## 1. Wirte K means function

# %% [markdown]
# import required libraries

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons

# %% [markdown]
# > ### 1.1. Code for the distance function

# %% [markdown]
# write a function to calculate the distance between a set of cluster centroids and all the data points
#
# Cluster_Distances = GUC_Distance ( Cluster_Centroids, Data_points, Distance_Type)
# * The function shoud be able to handel data points with any number of features and any number of points
# * The function should be able to handle any K number of cluster centroids
# * To inrease speed do that in matrix format using numpy
# * This should produce a matrix with rows equal to data points columns equal K
# * You should be able to calculate different types of Distance. In this assginmnet you are required to implement the following two
#     - Ecluidian distance
#     - Pearson correlation distance

# %%
# Distance_Type=1 will represent ecluidian distance , Distance_Type=2 will represent Pearson correlation distance

def GUC_Distance( Cluster_Centroids, Data_points, Distance_Type):
## write code here for the Distance function here # 
    min_array_of_index=[]
    
    for x in Data_points :
        tmp=[]
        for y in Cluster_Centroids :
             if(Distance_Type==1) :
                 tmp.append(distance.euclidean(x,y))
             else :
                 tmp.append(distance.correlation(x,y))
       
        min_array_of_index.append(tmp.index(min(tmp))) 
  
  
    new_centres=[]
    mean_sq_err=[]
    summation=0
    
    for i in range(0,len(np.unique(min_array_of_index))):
        tmp_arr=[]
        for j in range(0,len(Data_points)):
            
            if(i==min_array_of_index[j]):
             tmp_arr.append(Data_points[j])
             
        average = [sum(x)/len(x) for x in zip(*tmp_arr)]
        av=list(average)
       
        new_centres.append(average)
      
        
        
        for i in range (0,len(tmp_arr)):  #looping through each element of the list
                  # print (".............................................")
                  # print(average)
                  # print("kalabeezoo!!!!!!!!!!!!!!!!!!!!!!!!!!11")
                  
                  # print(tmp_arr[i])
                  # print(sum)
                 # MSE.append(mean_squared_error(tmp_arr[i],average))
                  d = {'col1': average, 'col2': tmp_arr[i]}
                  df = pd.DataFrame(data=d)
                  difference=df['col1']-df['col2']
                  
                  v2=list(tmp_arr[i])
                  d2=distance.euclidean(av, v2)
                  # d2=average- tmp_arr[i]
                  
                  
                  # print("hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh")
                  # print(difference)
                      # # difference = tmp_arr[i] - new_centres[j]  #finding the difference between observed and predicted value
                  squared_difference = difference**2  #taking square of the differene 
                  summation = summation + d2
                  # summation = summation + squared_difference  #taking a sum of all the differences
    MSE = summation/len(Data_points)  #dividing summation by total values to obtain average
    # MSE=MSE.sum()
    print ("The Mean Square Error is: " , MSE)
    
        

     
       
    return new_centres,MSE

# %% [markdown]
# > ### 1.2. Code for K means function

# %% [raw]
# Create the intial cluster heads
#  1. For each data colom find the data ranges
#  2. randomly generate a number of cluster heads equal to K (th number of clusters)

# %% [markdown]
# > Loop until a stopping condition
#
# > > in the loop do the following
# > > 1. Cluster Assginmnet
# > > > * Use the GUC_Distance to calculate between each cluster head and all the points
# > > > * Find the value and index of the minimum distance  for each row.
# > > > * for each point in the row use the index of the minmum distance to represent the cluster Centroid that this point will belong to.
# > > > * Calculate and record the mean square distance for each cluster
# > > > * Use the mean square distances to calculate a stopping condition (e.g the sum of mean distances)
# > > 2. Updtate Centroids
# > > > * Update the value for the cluster heads by calculating the mean value for the points in each cluster
# > > >  * Calculate the Cluster Metric (Distortion Function)
# > > > > a number indicating the how good the clusters are . An example cluster metric is the  (sum of squared error between each point and its cluster center)

# %%
def GUC_Kmean ( Data_points, Number_of_Clusters,  Distance_Type ):
       # write code for intial cluster heads here 
       # write your your loop 
    
    return [ Final_Cluster_Distance , Cluster_Metric ]

# %%
def distance_recursive(Cluster_Centroids) :
    
    print(Cluster_Centroids)
    new,new2=GUC_Distance(Cluster_Centroids,Data_points,Distance_Type)
  
    print(new)
    if(Cluster_Centroids==new):
        
        return new2
    else:
        
        return distance_recursive(new)
    
    
    

def initial_centre(Data_points,K) :
    x_list=[]
    y_list=[]
    for q in Data_points :
        
        x,y=q
        x_list.append(x)
        y_list.append(y)


    x_list_min=min(x_list)
    x_list_max=max(x_list)

    y_list_min=min(y_list)    
    y_list_max=max(y_list)

    
    
    Cluster_initial_centres=[]
    for i in range (0,K) :
        x_centre=random.randint(x_list_min,x_list_max)
        y_centre=random.randint(y_list_min,y_list_max)
        p=x_centre,y_centre
        Cluster_initial_centres.append(p)    
    return Cluster_initial_centres


def iterator(x):
    mse_arr=[]
    x_axis=[]
    for y in range(1,x+1):
        tmmmp=initial_centre(Data_points,y)
        print("")
        print("start")
        hamada=distance_recursive(tmmmp)
        # print(hamada)
        mse_arr.append(hamada)
        print("end")
        x_axis.append(y)

    plt.grid()
    plt.yticks(mse_arr)
    plt.xticks(x_axis)
    plt.plot(x_axis,mse_arr)
    
    
    return plt.show()

# %%
Data_points=[(2,1),(2,2),(10,13),(-1,-1),(0,0),(2,2),(25,25),(-2,-1),(2,5),(10,10)]

Distance_Type=1

iterator(3)
# Out:
# start
# [(18, 25)]
# The Mean Square Error is:  8.742571835842671
# [[5.0, 5.6]]
# [[5.0, 5.6]]
# The Mean Square Error is:  8.742571835842671
# [[5.0, 5.6]]
# end
#
# start
# [(25, 8), (2, 23)]
# The Mean Square Error is:  5.2832722995712995
# [[17.5, 17.5], [1.875, 2.625]]
# [[17.5, 17.5], [1.875, 2.625]]
# The Mean Square Error is:  4.309482311077028
# [[15.0, 16.0], [0.7142857142857143, 1.1428571428571428]]
# [[15.0, 16.0], [0.7142857142857143, 1.1428571428571428]]
# The Mean Square Error is:  4.309482311077028
# [[15.0, 16.0], [0.7142857142857143, 1.1428571428571428]]
# end
#
# start
# [(18, 21), (12, 22), (20, 2)]
# The Mean Square Error is:  1.8999997492944616
# [[25.0, 25.0], [10.0, 11.5], [0.7142857142857143, 1.1428571428571428]]
# [[25.0, 25.0], [10.0, 11.5], [0.7142857142857143, 1.1428571428571428]]
# The Mean Square Error is:  1.8999997492944616
# [[25.0, 25.0], [10.0, 11.5], [0.7142857142857143, 1.1428571428571428]]
# end

# %%
Data_points=[(2,1),(2,2),(10,13),(-1,-1),(0,0),(2,2),(25,25),(-2,-1),(2,5),(10,10)]

# %% [markdown]
# ## 2. Display Results

# %% [markdown]
# * below is a an example fuction that displayes Clusters in 2D
#
# * You need to change the function so that is can display an n dimension data in the form of pairs of subplot 2D figures
#
# * The function is a helper function that is originaly be found in
# https://www.coursera.org/learn/ibm-unsupervised-learning/

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt

# %% [markdown]
# > #### 2.1. helper Display function

# %%
# helper function that allows us to display data in 2 dimensions an highlights the clusters
#x= datapoints km = ceentroids
def display_cluster(X,km=[],num_clusters=0):
    color = 'brgcmyk'  #List colors
    alpha = 0.5  #color obaque
    s = 20
    if num_clusters == 0:
        plt.scatter(X[:,0],X[:,1],c = color[0],alpha = alpha,s = s)
    else:
            for i in range(num_clusters):
                plt.scatter(X[km.labels_==i,0],X[km.labels_==j,1],c = color[i],alpha = alpha,s=s)
                plt.scatter(km.cluster_centers_[i][0],km.cluster_centers_[i][1],c = color[i], marker = 'x', s = 100)

# %%
Data_points=[(2,1),(2,2),(10,13),(-1,-1),(0,0),(2,2),(25,25),(-2,-1),(2,5),(10,10)]
Distance_Type=1
num_clusters=2


k=initial_centre(Data_points,num_clusters)
km=distance_recursive(k)
X=[(2,1),(2,2),(10,13),(-1,-1),(0,0),(2,2),(25,25),(-2,-1),(2,5),(10,10)]

display_cluster(list(X),km,2)
# Out:
# [(22, 10), (19, 14)]
# The Mean Square Error is:  0.0
# [[]]
# [[]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12948/3142654173.py in <module>
#       5
#       6 k=initial_centre(Data_points,num_clusters)
# ----> 7 km=distance_recursive(k)
#       8 X=[(2,1),(2,2),(10,13),(-1,-1),(0,0),(2,2),(25,25),(-2,-1),(2,5),(10,10)]
#       9
#
# ~\AppData\Local\Temp/ipykernel_12948/63474110.py in distance_recursive(Cluster_Centroids)
#      10     else:
#      11
# ---> 12         return distance_recursive(new)
#      13
#      14
#
# ~\AppData\Local\Temp/ipykernel_12948/63474110.py in distance_recursive(Cluster_Centroids)
#       2
#       3     print(Cluster_Centroids)
# ----> 4     new,new2=GUC_Distance(Cluster_Centroids,Data_points,Distance_Type)
#       5
#       6     print(new)
#
# ...

# %% [markdown]
# > #### 2.2. Example 1 : Circular Data Gen and display

# %% [markdown]
# * below is an example of how to use the funciton
#   *  prepare the figure size and background
#    > * this part can be replaced by a number of subplots
#
#   * Produce a data set that represent the x and y o coordinates of a circle
#    > * this part can be replaced by data that you import froma file
#
#   * Data is displayed
#    > * to display the data only it is assumed that the number of clusters is zero which is the default of the fuction

# %%
# prepare the figure sise and background 
# this part can be replaced by a number of subplots 
plt.rcParams['figure.figsize'] = [8,8]
sns.set_style("whitegrid")
sns.set_context("talk")
# Produce a data set that represent the x and y o coordinates of a circle 
# this part can be replaced by data that you import froma file 
angle = np.linspace(0,2*np.pi,20, endpoint = False)
X = np.append([np.cos(angle)],[np.sin(angle)],0).transpose()
print(X)
# Data is displayed 
# to display the data only it is assumed that the number of clusters is zero which is the default of the fuction 
display_cluster(X)
# Out:
# [[ 1.00000000e+00  0.00000000e+00]
#  [ 9.51056516e-01  3.09016994e-01]
#  [ 8.09016994e-01  5.87785252e-01]
#  [ 5.87785252e-01  8.09016994e-01]
#  [ 3.09016994e-01  9.51056516e-01]
#  [ 6.12323400e-17  1.00000000e+00]
#  [-3.09016994e-01  9.51056516e-01]
#  [-5.87785252e-01  8.09016994e-01]
#  [-8.09016994e-01  5.87785252e-01]
#  [-9.51056516e-01  3.09016994e-01]
#  [-1.00000000e+00  1.22464680e-16]
#  [-9.51056516e-01 -3.09016994e-01]
#  [-8.09016994e-01 -5.87785252e-01]
#  [-5.87785252e-01 -8.09016994e-01]
#  [-3.09016994e-01 -9.51056516e-01]
#  [-1.83697020e-16 -1.00000000e+00]
#  [ 3.09016994e-01 -9.51056516e-01]
#  [ 5.87785252e-01 -8.09016994e-01]
#  [ 8.09016994e-01 -5.87785252e-01]
#  [ 9.51056516e-01 -3.09016994e-01]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12948/2504109858.py in <module>
#      11 # Data is displayed
# ...

# %% [markdown]
# > #### 2.3. Example 2 : Multi blob Data Gen and display

# %%
n_samples = 1000
n_bins = 4  
centers = [(-3, -3), (0, 0), (3, 3), (6, 6), (9,9)]
X, y = make_blobs(n_samples=n_samples, n_features=2, cluster_std=1.0,
                  centers=centers, shuffle=False, random_state=42)
display_cluster(X)

# %% [markdown]
# #### 2.3. Example 3 : moons Data Gen and display

# %%
n_samples = 1000
X, y = noisy_moons = make_moons(n_samples=n_samples, noise= .1)
display_cluster(X)

# %% [markdown]
# ## 3. Testing the GUC_Kmean function on Simple 2D
# 1. Apply the GUC_Kmean fucntion to 2D Data provided by example 1, Example 2 and Example 3
# 2. Try a varing number of cluster centriods that range from 2 to 10 clusters on each set
# 3. Display your results.
# 4. plot the Cluster perfromance Metric versus the number of clusters
# 4. Change the distance function and repeat the above steps

# %%
#Distance_Type=1
# prepare the figure sise and background 
# this part can be replaced by a number of subplots 
plt.rcParams['figure.figsize'] = [8,8]
sns.set_style("whitegrid")
sns.set_context("talk")
# Produce a data set that represent the x and y o coordinates of a circle 
# this part can be replaced by data that you import froma file 
angle = np.linspace(0,2*np.pi,20, endpoint = False)
X = np.append([np.cos(angle)],[np.sin(angle)],0).transpose()
print(X)
# Data is displayed 
# to display the data only it is assumed that the number of clusters is zero which is the default of the fuction 
#m=iterator(3)
display_cluster(X)
# Out:
# [[ 1.00000000e+00  0.00000000e+00]
#  [ 9.51056516e-01  3.09016994e-01]
#  [ 8.09016994e-01  5.87785252e-01]
#  [ 5.87785252e-01  8.09016994e-01]
#  [ 3.09016994e-01  9.51056516e-01]
#  [ 6.12323400e-17  1.00000000e+00]
#  [-3.09016994e-01  9.51056516e-01]
#  [-5.87785252e-01  8.09016994e-01]
#  [-8.09016994e-01  5.87785252e-01]
#  [-9.51056516e-01  3.09016994e-01]
#  [-1.00000000e+00  1.22464680e-16]
#  [-9.51056516e-01 -3.09016994e-01]
#  [-8.09016994e-01 -5.87785252e-01]
#  [-5.87785252e-01 -8.09016994e-01]
#  [-3.09016994e-01 -9.51056516e-01]
#  [-1.83697020e-16 -1.00000000e+00]
#  [ 3.09016994e-01 -9.51056516e-01]
#  [ 5.87785252e-01 -8.09016994e-01]
#  [ 8.09016994e-01 -5.87785252e-01]
#  [ 9.51056516e-01 -3.09016994e-01]]

# %% [markdown]
# ## 4. Using the GUC_Kmean function to segment customers int he provided customer dataset
# 1. Apply the GUC_Kmean fucntion to customer data
# 2. Try a varing number of cluster that range from 2 to 10 cluster on each set
# 3. Display your results.
# 4. plot the Cluster Metric versus the number of clusters
# 4. Change the distance function and repeat the above steps
